# %% [markdown]
# ## Image Matching Example

# %%
from src.ImageMatching import ImageMatching

# %%
image_paths = [
    r"./outputs/real/real_20240618_213201_unique/screenshot_0001.png",
    r"./outputs/real/real_20240618_213201_unique/screenshot_0004.png"
]

matcher = ImageMatching(image_paths)
matcher.plot_images()

# %%
matcher.plot_feature_matching()

# %%
matcher.plot_stitched_image()
