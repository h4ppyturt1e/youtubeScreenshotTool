# %% [markdown]
# ## Image Matching Example

# %%
from src.ImageMatching import ImageMatching

# %%
image_paths = [
    r"./outputs/from_the_start_laufey/from_the_start_laufey_20240620_141922_unique/screenshot_0004.png",
    r"./outputs/from_the_start_laufey/from_the_start_laufey_20240620_141922_unique/screenshot_0007.png"
]

matcher = ImageMatching(image_paths, overlap_region=300)
matcher.plot_images()

# %%
matcher.plot_feature_matching(do_print=False)

# %%
matcher.plot_stitched_image()
