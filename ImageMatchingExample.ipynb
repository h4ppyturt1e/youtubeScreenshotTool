# %% [markdown]
# ## Image Matching Example

# %%
from src.ImageMatching import ImageMatching

# %%
base_path =  r"./outputs/from_the_start_laufey/from_the_start_laufey_20240620_141922_unique/"
image_paths = [
    r"screenshot_0009.png",
    r"screenshot_0012.png"
]
image_paths = [base_path + path for path in image_paths]

# %%
matcher = ImageMatching(image_paths, overlap_region=300)
matcher.plot_images()

# %%
matcher.plot_feature_matching(do_print=False)

# %%
matcher.plot_stitched_image()
# Out:
# Stitching starts at img1: (465.0, 60.0) and img2: (74.0, 60.0)

# %%
from src.ImageMatching import StitchDirectory

# %%
stitcher = StitchDirectory(base_path, overlap_region=300)
# Out:
# Found 34 images in ./outputs/from_the_start_laufey/from_the_start_laufey_20240620_141922_unique/

# %%
stitcher.stitch_images(do_plot=False)
# Out:
# Final stitched image saved as c:\Users\ASUS\Documents\GitHub\youtubeScreenshotTool\outputs\from_the_start_laufey\final_stitched.png
