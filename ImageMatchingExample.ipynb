# %% [markdown]
# ## Image Matching Example

# %%
from src.ImageMatching import ImageMatching

# %%
base_path =  r"outputs/nothing - bruno major/nothing - bruno major_20250119_164547_unique/"
image_numbers = [32, 35]
image_paths = [f"screenshot_{num:04d}.png" for num in image_numbers]
print(image_paths)
image_paths = [base_path + path for path in image_paths]
# Out:
# ['screenshot_0032.png', 'screenshot_0035.png']

# %%
SET_OVERRIDE = 200
TOP_N = 0
MANUAL_OVERRIDE = []
matcher = ImageMatching(image_paths, overlap_region=SET_OVERRIDE,
                        use_top_n=TOP_N, manual_override=MANUAL_OVERRIDE)

matcher.plot_images()

# %%
matcher.plot_feature_matching(do_print=False)

# %%
matcher.plot_stitched_image()
# Out:
# Stitching starts at img1: (496.0, 63.0) and img2: (48.0, 63.0)

# %%
from src.ImageMatching import StitchDirectory

# %%
stitcher = StitchDirectory(base_path, overlap_region=300)
stitcher.set_stitch_params(image_numbers[-1], SET_OVERRIDE, TOP_N, MANUAL_OVERRIDE)
stitcher.stitch_images(do_plot=False)
formatted_img = stitcher.format_stitched_image(threshold=1000, padding=10)
stitcher.convert_to_pdf(formatted_img)
# Out:
# Found 27 images in outputs/nothing - bruno major/nothing - bruno major_20250119_164547_unique/
# Overriding existing values for image #35 with new values
# Final stitched image saved as c:\Users\ASUS\Documents\GitHub\youtubeScreenshotTool\outputs\nothing - bruno major\final_stitched.png
# Formatted stitched image saved as c:\Users\ASUS\Documents\GitHub\youtubeScreenshotTool\outputs\nothing - bruno major\formatted_stitched.png
# Deleted existing PDF: c:\Users\ASUS\Documents\GitHub\youtubeScreenshotTool\outputs\nothing - bruno major\formatted_stitched.pdf
# Converted c:\Users\ASUS\Documents\GitHub\youtubeScreenshotTool\outputs\nothing - bruno major\formatted_stitched.png to c:\Users\ASUS\Documents\GitHub\youtubeScreenshotTool\outputs\nothing - bruno major\formatted_stitched.pdf
